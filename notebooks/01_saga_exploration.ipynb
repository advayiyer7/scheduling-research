# %% [markdown]
# # SAGA Framework Exploration

# %%
# Check SAGA installation
try:
    import saga
    print('SAGA installed!')
except ImportError:
    print('Run: cd saga && pip install -e .')

# %%
# Import schedulers
from saga.schedulers import HeftScheduler, CpopScheduler
print('Schedulers loaded!')

# %% [markdown]
# ## Next Steps
# 1. Run `saga/scripts/examples/basic_usage/main.py`
# 2. Read `saga/src/saga/schedulers/heft.py`
# 3. Add annotations to docs/heft_annotations.md
